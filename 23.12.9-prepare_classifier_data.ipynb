# %%
import numpy as np
import os

# %%
axel_server_path = ('/').join(os.getcwd().split('/')[:3])+'/engram/'

# %%
def read_txt_file(file_path):
    final_content =[]
    with open(file_path, 'r') as file:
        content = file.readlines()
        for line in content:
            line = line.strip()
            line = line.split(':')
            final_content.append(line)
    return final_content

# %%
axel_server_path
# Out:
# '/home/es3773/engram/'

# %%
data_path = '/home/es3773/engram/es3773/data/mask_classifier_data'
folders = os.listdir(data_path)

# %%
folders
# Out:
# ['2023-04-28_Bubbles_Quilt_50_25q-120s_25b-120s_alt_c2023-04-21',
#  '2023-08-08_TRex_Quilt_Set_a-b_43_21q-120s_22b-120s_alt_c2023-07-23',
#  '2023-09-28_Iguanodon_Quilt_Set_b-bw_43_21q-120s_22b-120s_alt_c2023-07-23_pop',
#  '2023-05-09_Barry_Quilt_51_25q-120s_26b-120s_alt_c2023-04-21',
#  '2023-08-29_Iguanodon_Quilt_Set_b-b_43_21q-120s_22b-120s_alt_c2023-07-23',
#  '2023-08-15_TRex_Quilt_Set_a-bw_43_21q-120s_22b-120s_alt_c2023-07-23',
#  '2023-04-25_Bubbles_Quilt_50_25q-120s_25b-120s_alt_c2023-04-21',
#  '.DS_Store',
#  '2023-08-10_Tom_Quilt_Set_a-b_43_21q-120s_22b-120s_alt_c2023-07-23',
#  '2023-05-05_Rocky_Quilt_51_25q-120s_26b-120s_alt_c2023-04-21',
#  '2023-05-12_Barry_Quilt_51_25q-120s_26b-120s_alt_c2023-04-21',
#  '2023-09-28_Iguanodon_Quilt_Set_b-bw_43_21q-120s_22b-120s_alt_c2023-07-23_lightroom',
#  '2023-08-28_Iguanodon_Quilt_Set_a-bw_43_21q-120s_22b-120s_alt_c2023-07-23',
#  '2023-07-05_Tom_Quilt_51_25q-120s_26b-120s_alt_c2023-04-21',
# ...

# %%
data_dict = {}
for folder in folders:
    if folder != '.DS_Store':
        for f in os.listdir(data_path+'/'+folder):
            if '.txt' in f :
                data_dict[folder] = read_txt_file(data_path+'/'+folder+'/'+f)

# %%
data_dict.keys()
# Out:
# dict_keys(['2023-04-28_Bubbles_Quilt_50_25q-120s_25b-120s_alt_c2023-04-21', '2023-08-15_TRex_Quilt_Set_a-bw_43_21q-120s_22b-120s_alt_c2023-07-23', '2023-04-25_Bubbles_Quilt_50_25q-120s_25b-120s_alt_c2023-04-21', '2023-08-10_Tom_Quilt_Set_a-b_43_21q-120s_22b-120s_alt_c2023-07-23', '2023-05-05_Rocky_Quilt_51_25q-120s_26b-120s_alt_c2023-04-21', '2023-05-12_Barry_Quilt_51_25q-120s_26b-120s_alt_c2023-04-21', '2023-08-28_Iguanodon_Quilt_Set_a-bw_43_21q-120s_22b-120s_alt_c2023-07-23', '2023-09-26_Iguanodon_Quilt_Set_b-b_rev_43_21q-120s_22b-120s_alt_c2023-07-23', '2023-05-02_Bubbles_Quilt_50_25q-120s_25b-120s_alt_c2023-04-21', '2023-08-30_trex_quilt_set_b-b_43_21q-120s_22b-120s_alt_c2023-07-23', '2023-09-25_Tom_Quilt_Set_b-b_rev_43_21q-120s_22b-120s_alt_c2023-07-23', '2023-04-21_Bubbles_Quilt_50_25q-120s_25b-120s_alt_c2023-04-21', '2023-08-16_Tom_Quilt_Set_a-bw_43_21q-120s_22b-120s_alt_c2023-07-23', '2023-08-17_Tom_Quilt_Set_b-b_43_21q-120s_22b-120s_alt_c2023-07-23', '2023-09-27_Tom_Quilt_Se
# ...

# %%
data_dict[folder][0]
# Out:
# ['cf_2023-04-28_Bubbles_Quilt_50_25q-120s_25b-120s_alt_c2023-04-21_1.png',
#  ' 1']

# %%
import shutil

source_path = '/path/to/source/file.txt'
destination_path = '/path/to/destination/file.txt'

shutil.copy(source_path, destination_path)

# %%
import shutil

def move_image(source_path, destination_path):
    try:
        shutil.move(source_path, destination_path)
        print("Image moved successfully!")
    except FileNotFoundError:
        print("Source file not found.")
    except PermissionError:
        print("Permission denied. Unable to move the image.")

# %%
## Need to move each image w/ correct name
## Need to move the same number of bg images 


key = folder
print(folder)
# Out:
# 2023-04-28_Bubbles_Quilt_50_25q-120s_25b-120s_alt_c2023-04-21

# %%
os.listdir(data_path+'/'+folder+'/masks')
# Out:
# ['bg_0_2023-04-28_Bubbles_Quilt_50_25q-120s_25b-120s_alt_c2023-04-21_3651.png',
#  'bg_1_2023-04-28_Bubbles_Quilt_50_25q-120s_25b-120s_alt_c2023-04-21_1302.png',
#  'cf_2023-04-28_Bubbles_Quilt_50_25q-120s_25b-120s_alt_c2023-04-21_1457.png',
#  'cf_2023-04-28_Bubbles_Quilt_50_25q-120s_25b-120s_alt_c2023-04-21_39.png',
#  'cf_2023-04-28_Bubbles_Quilt_50_25q-120s_25b-120s_alt_c2023-04-21_3813.png',
#  'bg_1_2023-04-28_Bubbles_Quilt_50_25q-120s_25b-120s_alt_c2023-04-21_1174.png',
#  'cf_2023-04-28_Bubbles_Quilt_50_25q-120s_25b-120s_alt_c2023-04-21_3902.png',
#  'cf_2023-04-28_Bubbles_Quilt_50_25q-120s_25b-120s_alt_c2023-04-21_2319.png',
#  'bg_0_2023-04-28_Bubbles_Quilt_50_25q-120s_25b-120s_alt_c2023-04-21_478.png',
#  'cf_2023-04-28_Bubbles_Quilt_50_25q-120s_25b-120s_alt_c2023-04-21_2516.png',
#  'cf_2023-04-28_Bubbles_Quilt_50_25q-120s_25b-120s_alt_c2023-04-21_1884.png',
#  'cf_2023-04-28_Bubbles_Quilt_50_25q-120s_25b-120s_alt_c2023-04-21_2392.png',
# ...

# %%
key = list(data_dict.keys())[0]

# %%
key
source_path = data_path+'/'+folder+'/masks/'+entry[0]

# %%
data_dict.keys(
    
)
# Out:
# dict_keys(['2023-04-28_Bubbles_Quilt_50_25q-120s_25b-120s_alt_c2023-04-21'])

# %%
curr_data
# Out:
# [['cf_2023-04-28_Bubbles_Quilt_50_25q-120s_25b-120s_alt_c2023-04-21_1.png',
#   ' 1'],
#  ['cf_2023-04-28_Bubbles_Quilt_50_25q-120s_25b-120s_alt_c2023-04-21_10.png',
#   ' 0'],
#  ['cf_2023-04-28_Bubbles_Quilt_50_25q-120s_25b-120s_alt_c2023-04-21_100.png',
#   ' 0'],
#  ['cf_2023-04-28_Bubbles_Quilt_50_25q-120s_25b-120s_alt_c2023-04-21_1001.png',
#   ' 1'],
#  ['cf_2023-04-28_Bubbles_Quilt_50_25q-120s_25b-120s_alt_c2023-04-21_101.png',
#   ' 1'],
#  ['cf_2023-04-28_Bubbles_Quilt_50_25q-120s_25b-120s_alt_c2023-04-21_1015.png',
#   ' 1'],
#  ['cf_2023-04-28_Bubbles_Quilt_50_25q-120s_25b-120s_alt_c2023-04-21_1016.png',
#   ' 1'],
#  ['cf_2023-04-28_Bubbles_Quilt_50_25q-120s_25b-120s_alt_c2023-04-21_1018.png',
#   ' 1'],
#  ['cf_2023-04-28_Bubbles_Quilt_50_25q-120s_25b-120s_alt_c2023-04-21_102.png',
#   ' 0'],
#  ['cf_2023-04-28_Bubbles_Quilt_50_25q-120s_25b-120s_alt_c2023-04-21_1030.png',
#   ' 1'],
#  ['cf_2023-04-28_Bubbles_Quilt_50_25q-120s_25b-120s_alt_c2023-04-21_1031.png',
# ...

# %%
os.mkdir('/home/es3773/engram/es3773/data/final_data_for_mask_classifier_manual_labels_temp')

# %%
source_path
# Out:
# '/home/es3773/engram/es3773/data/mask_classifier_data/2023-08-09_TRex_Quilt_Set_a-b_rev_43_21q-120s_22b-120s_alt_c2023-07-23/masks/cf_2023-04-28_Bubbles_Quilt_50_25q-120s_25b-120s_alt_c2023-04-21_10.png'

# %%
os.mkdir('/home/es3773/engram/es3773/data/final_data_for_mask_classifier_manual_labels_folder/')
for key in data_dict.keys():
    data_path = '/home/es3773/engram/es3773/data/mask_classifier_data'
    print(key)
    curr_data = data_dict[key]
    try:
         os.mkdir('/home/es3773/engram/es3773/data/final_data_for_mask_classifier_manual_labels_folder/'+key+'/')
    except:
        pass
    for ii, entry in enumerate(curr_data):
        print(ii)
        source_path = data_path+'/'+key+'/masks/'+entry[0]
        print(source_path)
       
        if entry[1].strip() == '1':
            destination_path = '/home/es3773/engram/es3773/data/final_data_for_mask_classifier_manual_labels_folder/'+key+'/'+entry[0]
            move_image(source_path, destination_path)
        elif entry[1].strip() == '2':
            if entry[0].split('_')[0]=='cf':
                destination_path = '/home/es3773/engram/es3773/data/final_data_for_mask_classifier_manual_labels_folder/'+key+'/'+entry[0].replace('cf', 'mantle')
                move_image(source_path, destination_path)
            else:
                destination_path = '/home/es3773/engram/es3773/data/final_data_for_mask_classifier_manual_labels_folder/'+key+'/'+entry[0].replace('mantle', 'cf')
                move_image(source_path, destination_path)
# Out:
# ---------------------------------------------------------------------------
# FileExistsError                           Traceback (most recent call last)
# /home/es3773/cuttledata/23.12.9-prepare_classifier_data.ipynb Cell 22 line 1
# ----> <a href='vscode-notebook-cell://ssh-remote%2Bgpu01.axel.zi.columbia.edu/home/es3773/cuttledata/23.12.9-prepare_classifier_data.ipynb#X25sdnNjb2RlLXJlbW90ZQ%3D%3D?line=0'>1</a> os.mkdir('/home/es3773/engram/es3773/data/final_data_for_mask_classifier_manual_labels_folder/')
#       <a href='vscode-notebook-cell://ssh-remote%2Bgpu01.axel.zi.columbia.edu/home/es3773/cuttledata/23.12.9-prepare_classifier_data.ipynb#X25sdnNjb2RlLXJlbW90ZQ%3D%3D?line=1'>2</a> for key in data_dict.keys():
#       <a href='vscode-notebook-cell://ssh-remote%2Bgpu01.axel.zi.columbia.edu/home/es3773/cuttledata/23.12.9-prepare_classifier_data.ipynb#X25sdnNjb2RlLXJlbW90ZQ%3D%3D?line=2'>3</a>     data_path = '/home/es3773/engram/es3773/data/mask_classifier_data'
#
# ...

# %%
key
# Out:
# '2023-04-28_Bubbles_Quilt_50_25q-120s_25b-120s_alt_c2023-04-21'

# %%
print(len(os.listdir('/home/es3773/engram/es3773/data/final_data_for_mask_classifier_manual_labels/')))
# Out:
# 2020

# %%
files = os.listdir('/home/es3773/engram/es3773/data/final_data_for_mask_classifier_manual_labels/')

# %%
files[0]
# Out:
# 'cf_2023-08-16_Tom_Quilt_Set_a-bw_43_21q-120s_22b-120s_alt_c2023-07-23_126.png'

# %%
bg_files = [f for f in os.listdir('
/final_data_for_mask_classifier') if 'bg' in f]

# %%
len(bg_files)
# Out:
# 98272

# %%
mantle_files = [f for f in os.listdir('/home/es3773/engram/es3773/data/final_data_for_mask_classifier_manual_labels') if 'mantle' in f]

# %%
len(files)
# Out:
# 161427

# %%
len(mantle_files)
# Out:
# 48465

# %%
cf_files = [f for f in os.listdir('/home/es3773/engram/es3773/data/final_data_for_mask_classifier_manual_labels') if 'cf' in f]

# %%
len(cf_files)
# Out:
# 64497

# %%
bg_files[0:10]
# Out:
# ['bg_1_2023-09-26_Iguanodon_Quilt_Set_b-b_rev_43_21q-120s_22b-120s_alt_c2023-07-23_255.png',
#  'bg_0_2023-04-28_Bubbles_Quilt_50_25q-120s_25b-120s_alt_c2023-04-21_3651.png',
#  'bg_1_2023-04-28_Bubbles_Quilt_50_25q-120s_25b-120s_alt_c2023-04-21_1302.png',
#  'bg_1_2023-05-09_Barry_Quilt_51_25q-120s_26b-120s_alt_c2023-04-21_3265.png',
#  'bg_0_2023-08-08_TRex_Quilt_Set_a-b_43_21q-120s_22b-120s_alt_c2023-07-23_280.png',
#  'bg_0_2023-07-03_Tom_Quilt_51_25q-120s_26b-120s_alt_c2023-04-21_3623.png',
#  'bg_0_2023-06-30_Tom_Quilt_51_25q-120s_26b-120s_alt_c2023-04-21_1518.png',
#  'bg_0_2023-06-30_Tom_Quilt_51_25q-120s_26b-120s_alt_c2023-04-21_3700.png',
#  'bg_0_2023-09-28_Iguanodon_Quilt_Set_b-bw_43_21q-120s_22b-120s_alt_c2023-07-23_1715.png',
#  'bg_0_2023-08-30_trex_quilt_set_b-b_43_21q-120s_22b-120s_alt_c2023-07-23_630.png']

# %%
for ii in range(48465):
    
    print(ii)
    source_path = '/home/es3773/engram/es3773/data/final_data_for_mask_classifier/'+bg_files[ii]
    destination_path = '/home/es3773/engram/es3773/data/final_data_for_mask_classifier_manual_labels/'+bg_files[ii]
    move_image(source_path, destination_path)
# Out:
# 0
# Image moved successfully!
# 1
# Image moved successfully!
# 2
# Image moved successfully!
# 3
# Image moved successfully!
# 4
# Image moved successfully!
# 5
# Image moved successfully!
# 6
# Image moved successfully!
# 7
# Image moved successfully!
# 8
# Image moved successfully!
# 9
# Image moved successfully!
# 10
# Image moved successfully!
# 11
# Image moved successfully!
# 12
# Image moved successfully!
# 13
# Image moved successfully!
# 14
# Image moved successfully!
# 15
# Image moved successfully!
# 16
# Image moved successfully!
# 17
# Image moved successfully!
# 18
# Image moved successfully!
# 19
# Image moved successfully!
# 20
# Image moved successfully!
# 21
# Image moved successfully!
# 22
# Image moved successfully!
# 23
# Image moved successfully!
# 24
# Image moved successfully!
# 25
# Image moved successfully!
# 26
# Image moved successfully!
# 27
# Image moved successfully!
# 28
# Image moved successfully!
# 29
# Image moved successfully!
# 30
# ...

# %%
print('hello')
